# %%
from compare_semi_supervised_clustering import *

# %%
    x_train, y_train, x_test, y_test = load_data()
    percentages = [0.02, 0.05, 0.1, 0.2, 0.5]
    rounds = 5

    methods = {
        "SemiSupervisedGMM": SemiSupervisedGMM,
        "LabelPropagation": LabelPropagation,
        "SVC": SVC,
        "CopKMean": CopKMean,
    }

    methods_accs = []
    for Method in tqdm(methods.values(), desc="methods"):
        accs = []  # Temporarily store accuracies for the current method
        for percentage in tqdm(percentages, desc=">> percentages"):
            # Prepare labeled and unlabeled data
            labeled_data, labeled_labels, unlabeled_data, unlabeled_labels = prepare_labeled_data(
                x_train, y_train, percentage=percentage)
            X = np.concatenate((labeled_data, unlabeled_data), axis=0)

            accs_round = []
            for _ in tqdm(range(rounds), desc="rounds"):
                model = fit_method(Method, X, labeled_data, labeled_labels, unlabeled_data, unlabeled_labels)
                cluster_assignments = model.predict(X)
                accs_round.append(clustering_accuracy(unlabeled_labels, cluster_assignments[len(labeled_labels):]))
            accs.append(accs_round)
        methods_accs.append(accs)
# Out:
# methods:   0%|          | 0/4 [00:00<?, ?it/s]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:00<00:03,  1.03it/s]
#
# rounds:  40%|████      | 2/5 [00:01<00:02,  1.03it/s]
#
# rounds:  60%|██████    | 3/5 [00:02<00:01,  1.05it/s]
#
# rounds:  80%|████████  | 4/5 [00:03<00:00,  1.03it/s]
#
# rounds: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
#
# >> percentages:  20%|██        | 1/5 [00:04<00:19,  4.94s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:01<00:04,  1.24s/it]
#
# rounds:  40%|████      | 2/5 [00:02<00:03,  1.22s/it]
#
# rounds:  60%|██████    | 3/5 [00:03<00:02,  1.20s/it]
#
# rounds:  80%|████████  | 4/5 [00:04<00:01,  1.21s/it]
#
# rounds: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
#
# >> percentages:  40%|████      | 2/5 [00:10<00:15,  5.25s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:01<00:06,  1.63s/it]
#
# rounds:  40%|████      | 2/5 [00:03<00:04,  1.63s/it]
#
# rounds:  60%|██████    | 3/5 [00:04<00:03,  1.63s/it]
#
# rounds:  80%|████████  | 4/5 [00:06<00:01,  1.62s/it]
#
# rounds: 100%|██████████| 5/5 [00:08<00:00,  1.62s/it]
#
# >> percentages:  60%|██████    | 3/5 [00:19<00:12,  6.11s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:01<00:07,  1.85s/it]
#
# rounds:  40%|████      | 2/5 [00:03<00:05,  1.77s/it]
#
# rounds:  60%|██████    | 3/5 [00:05<00:03,  1.73s/it]
#
# rounds:  80%|████████  | 4/5 [00:06<00:01,  1.73s/it]
#
# rounds: 100%|██████████| 5/5 [00:08<00:00,  1.69s/it]
#
# >> percentages:  80%|████████  | 4/5 [00:27<00:06,  6.82s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:02<00:10,  2.74s/it]
#
# rounds:  40%|████      | 2/5 [00:05<00:08,  2.75s/it]
#
# rounds:  60%|██████    | 3/5 [00:08<00:05,  2.75s/it]
#
# rounds:  80%|████████  | 4/5 [00:10<00:02,  2.74s/it]
#
# rounds: 100%|██████████| 5/5 [00:13<00:00,  2.75s/it]
#
# >> percentages: 100%|██████████| 5/5 [00:41<00:00,  8.26s/it]
# methods:  25%|██▌       | 1/4 [00:41<02:03, 41.29s/it]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:02<00:09,  2.28s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:04<00:06,  2.27s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:06<00:04,  2.27s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:09<00:02,  2.29s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:11<00:00,  2.28s/it]
#
# >> percentages:  20%|██        | 1/5 [00:11<00:45, 11.41s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:02<00:08,  2.21s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:04<00:06,  2.21s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:06<00:04,  2.22s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:08<00:02,  2.21s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:11<00:00,  2.20s/it]
#
# >> percentages:  40%|████      | 2/5 [00:22<00:33, 11.30s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:02<00:08,  2.22s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:04<00:06,  2.22s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:06<00:04,  2.20s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:08<00:02,  2.18s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:10<00:00,  2.18s/it]
#
# >> percentages:  60%|██████    | 3/5 [00:33<00:22, 11.19s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:02<00:08,  2.11s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:04<00:06,  2.11s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:06<00:04,  2.12s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:08<00:02,  2.14s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:10<00:00,  2.15s/it]
#
# >> percentages:  80%|████████  | 4/5 [00:44<00:11, 11.07s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
# rounds:  20%|██        | 1/5 [00:02<00:08,  2.07s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:04<00:06,  2.07s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:06<00:04,  2.07s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:08<00:02,  2.06s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:10<00:00,  2.05s/it]
#
# >> percentages: 100%|██████████| 5/5 [00:54<00:00, 10.89s/it]
# methods:  50%|█████     | 2/4 [01:35<01:30, 45.24s/it]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:00<00:01,  2.82it/s]
#
# rounds:  40%|████      | 2/5 [00:00<00:01,  2.92it/s]
#
# rounds:  60%|██████    | 3/5 [00:00<00:00,  2.98it/s]
#
# rounds:  80%|████████  | 4/5 [00:01<00:00,  3.02it/s]
#
# rounds: 100%|██████████| 5/5 [00:01<00:00,  3.05it/s]
#
# >> percentages:  20%|██        | 1/5 [00:01<00:06,  1.66s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:00<00:03,  1.26it/s]
#
# rounds:  40%|████      | 2/5 [00:01<00:02,  1.20it/s]
#
# rounds:  60%|██████    | 3/5 [00:02<00:01,  1.08it/s]
#
# rounds:  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
#
# rounds: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
#
# >> percentages:  40%|████      | 2/5 [00:07<00:08,  2.78s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:02<00:09,  2.36s/it]
#
# rounds:  40%|████      | 2/5 [00:03<00:06,  2.14s/it]
#
# rounds:  60%|██████    | 3/5 [00:05<00:03,  1.95s/it]
#
# rounds:  80%|████████  | 4/5 [00:07<00:01,  1.82s/it]
#
# rounds: 100%|██████████| 5/5 [00:08<00:00,  1.69s/it]
#
# >> percentages:  60%|██████    | 3/5 [00:15<00:08,  4.50s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:02<00:11,  2.78s/it]
#
# rounds:  40%|████      | 2/5 [00:05<00:08,  2.81s/it]
#
# rounds:  60%|██████    | 3/5 [00:08<00:05,  2.83s/it]
#
# rounds:  80%|████████  | 4/5 [00:11<00:02,  2.82s/it]
#
# rounds: 100%|██████████| 5/5 [00:14<00:00,  2.82s/it]
#
# >> percentages:  80%|████████  | 4/5 [00:29<00:07,  7.39s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:06<00:26,  6.56s/it]
#
# rounds:  40%|████      | 2/5 [00:13<00:19,  6.57s/it]
#
# rounds:  60%|██████    | 3/5 [00:19<00:13,  6.56s/it]
#
# rounds:  80%|████████  | 4/5 [00:26<00:06,  6.63s/it]
#
# rounds: 100%|██████████| 5/5 [00:33<00:00,  6.61s/it]
#
# >> percentages: 100%|██████████| 5/5 [01:02<00:00, 12.56s/it]
# methods:  75%|███████▌  | 3/4 [02:38<00:50, 50.51s/it]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:02<00:09,  2.37s/it]
#
# rounds:  40%|████      | 2/5 [00:04<00:06,  2.22s/it]
#
# rounds:  60%|██████    | 3/5 [00:07<00:05,  2.53s/it]
#
# rounds:  80%|████████  | 4/5 [00:08<00:02,  2.07s/it]
#
# rounds: 100%|██████████| 5/5 [00:09<00:00,  1.88s/it]
#
# >> percentages:  20%|██        | 1/5 [00:09<00:37,  9.45s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:02<00:10,  2.74s/it]
#
# rounds:  40%|████      | 2/5 [00:05<00:07,  2.63s/it]
#
# rounds:  60%|██████    | 3/5 [00:07<00:05,  2.55s/it]
#
# rounds:  80%|████████  | 4/5 [00:09<00:02,  2.46s/it]
#
# rounds: 100%|██████████| 5/5 [00:11<00:00,  2.37s/it]
#
# >> percentages:  40%|████      | 2/5 [00:21<00:30, 10.18s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:06<00:24,  6.14s/it]
#
# rounds:  40%|████      | 2/5 [00:15<00:21,  7.22s/it]
#
# rounds:  60%|██████    | 3/5 [00:19<00:12,  6.26s/it]
#
# rounds:  80%|████████  | 4/5 [00:23<00:05,  5.61s/it]
#
# rounds: 100%|██████████| 5/5 [00:27<00:00,  5.42s/it]
#
# >> percentages:  60%|██████    | 3/5 [00:48<00:30, 15.26s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [01:36<06:24, 96.17s/it]
#
# rounds:  40%|████      | 2/5 [01:53<03:37, 72.54s/it]
#
# rounds:  60%|██████    | 3/5 [02:48<02:14, 67.31s/it]
#
# rounds:  80%|████████  | 4/5 [03:01<00:51, 51.09s/it]
#
# rounds: 100%|██████████| 5/5 [04:40<00:00, 56.20s/it]
#
# >> percentages:  80%|████████  | 4/5 [05:29<01:34, 94.99s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [08:22<33:30, 502.63s/it]
#
# rounds:  40%|████      | 2/5 [16:39<25:02, 500.96s/it]
#
# rounds:  60%|██████    | 3/5 [25:11<16:48, 504.12s/it]
#
# rounds:  80%|████████  | 4/5 [33:31<08:22, 502.94s/it]
#
# rounds: 100%|██████████| 5/5 [41:55<00:00, 503.03s/it]
#
# >> percentages: 100%|██████████| 5/5 [47:24<00:00, 568.92s/it]
# methods: 100%|██████████| 4/4 [50:03<00:00, 750.79s/it]

# %%
plot_multi_method_accs(methods_accs, percentages, methods.keys())

# %%
    x_train, y_train, x_test, y_test = load_data("cifar10")
    percentages = [0.02, 0.05, 0.1, 0.2, 0.5]
    rounds = 5

    methods = {
        "SemiSupervisedGMM": SemiSupervisedGMM,
        "LabelPropagation": LabelPropagation,
        "SVC": SVC,
        "CopKMean": CopKMean,
    }

    methods_accs = []
    for Method in tqdm(methods.values(), desc="methods"):
        accs = []  # Temporarily store accuracies for the current method
        for percentage in tqdm(percentages, desc=">> percentages"):
            # Prepare labeled and unlabeled data
            labeled_data, labeled_labels, unlabeled_data, unlabeled_labels = prepare_labeled_data(
                x_train, y_train, percentage=percentage)
            X = np.concatenate((labeled_data, unlabeled_data), axis=0)

            accs_round = []
            for _ in tqdm(range(rounds), desc="rounds"):
                model = fit_method(Method, X, labeled_data, labeled_labels, unlabeled_data, unlabeled_labels)
                cluster_assignments = model.predict(X)
                accs_round.append(clustering_accuracy(unlabeled_labels, cluster_assignments[len(labeled_labels):]))
            accs.append(accs_round)
        methods_accs.append(accs)
# Out:
# methods:   0%|          | 0/4 [00:00<?, ?it/s]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:11<00:47, 11.79s/it]
#
# rounds:  40%|████      | 2/5 [00:26<00:38, 12.73s/it]
#
# rounds:  60%|██████    | 3/5 [00:39<00:25, 12.62s/it]
#
# rounds:  80%|████████  | 4/5 [00:50<00:12, 12.39s/it]
#
# rounds: 100%|██████████| 5/5 [01:02<00:00, 12.48s/it]
#
# >> percentages:  20%|██        | 1/5 [01:02<04:09, 62.48s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:12<00:49, 12.35s/it]
#
# rounds:  40%|████      | 2/5 [00:30<00:42, 14.08s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/mixture/_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
#
#
# rounds:  60%|██████    | 3/5 [00:54<00:33, 16.98s/it]
#
# rounds:  80%|████████  | 4/5 [01:09<00:16, 16.59s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/mixture/_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
#
#
# rounds: 100%|██████████| 5/5 [01:25<00:00, 17.05s/it]
#
# >> percentages:  40%|████      | 2/5 [02:27<03:27, 69.32s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:07<00:31,  7.98s/it]
#
# rounds:  40%|████      | 2/5 [00:16<00:24,  8.10s/it]
#
# rounds:  60%|██████    | 3/5 [00:23<00:15,  7.74s/it]
#
# rounds:  80%|████████  | 4/5 [00:30<00:07,  7.45s/it]
#
# rounds: 100%|██████████| 5/5 [00:37<00:00,  7.50s/it]
#
# >> percentages:  60%|██████    | 3/5 [03:05<01:59, 59.79s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:11<00:46, 11.57s/it]
#
# rounds:  40%|████      | 2/5 [00:22<00:34, 11.52s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/mixture/_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
#
#
# rounds:  60%|██████    | 3/5 [00:40<00:26, 13.18s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/mixture/_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
#
#
# rounds:  80%|████████  | 4/5 [00:57<00:14, 14.37s/it]
#
# rounds: 100%|██████████| 5/5 [01:08<00:00, 13.68s/it]
#
# >> percentages:  80%|████████  | 4/5 [04:13<01:02, 62.40s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:13<00:55, 13.82s/it]
#
# rounds:  40%|████      | 2/5 [00:28<00:42, 14.22s/it]
#
# rounds:  60%|██████    | 3/5 [00:44<00:28, 14.50s/it]
#
# rounds:  80%|████████  | 4/5 [01:01<00:15, 15.41s/it]
#
# rounds: 100%|██████████| 5/5 [01:19<00:00, 15.82s/it]
#
# >> percentages: 100%|██████████| 5/5 [05:32<00:00, 66.60s/it]
# methods:  25%|██▌       | 1/4 [05:32<16:38, 332.98s/it]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:03<00:13,  3.28s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:06<00:09,  3.24s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:09<00:06,  3.24s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:13<00:03,  3.43s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:17<00:00,  3.51s/it]
#
# >> percentages:  20%|██        | 1/5 [00:17<01:10, 17.62s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:04<00:16,  4.06s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:08<00:12,  4.08s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:11<00:07,  3.92s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:15<00:03,  3.77s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:18<00:00,  3.77s/it]
#
# >> percentages:  40%|████      | 2/5 [00:36<00:54, 18.03s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:04<00:17,  4.29s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:07<00:12,  4.06s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:11<00:07,  3.86s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:14<00:03,  3.72s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:18<00:00,  3.64s/it]
#
# >> percentages:  60%|██████    | 3/5 [00:54<00:36, 18.10s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:03<00:15,  3.76s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
# rounds:  40%|████      | 2/5 [00:07<00:10,  3.62s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:10<00:07,  3.51s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:13<00:03,  3.46s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:16<00:00,  3.39s/it]
#
# >> percentages:  80%|████████  | 4/5 [01:11<00:17, 17.78s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  20%|██        | 1/5 [00:03<00:12,  3.24s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  40%|████      | 2/5 [00:06<00:09,  3.26s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  60%|██████    | 3/5 [00:09<00:06,  3.30s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds:  80%|████████  | 4/5 [00:13<00:03,  3.32s/it]/home/congyu/anaconda3/envs/congyuAI/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#
#
# rounds: 100%|██████████| 5/5 [00:16<00:00,  3.32s/it]
#
# >> percentages: 100%|██████████| 5/5 [01:28<00:00, 17.71s/it]
# methods:  50%|█████     | 2/4 [07:01<08:39, 259.65s/it]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:01<00:05,  1.30s/it]
#
# rounds:  40%|████      | 2/5 [00:02<00:04,  1.35s/it]
#
# rounds:  60%|██████    | 3/5 [00:04<00:02,  1.33s/it]
#
# rounds:  80%|████████  | 4/5 [00:05<00:01,  1.37s/it]
#
# rounds: 100%|██████████| 5/5 [00:06<00:00,  1.36s/it]
#
# >> percentages:  20%|██        | 1/5 [00:06<00:27,  6.85s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:04<00:17,  4.46s/it]
#
# rounds:  40%|████      | 2/5 [00:08<00:13,  4.40s/it]
#
# rounds:  60%|██████    | 3/5 [00:12<00:08,  4.34s/it]
#
# rounds:  80%|████████  | 4/5 [00:17<00:04,  4.32s/it]
#
# rounds: 100%|██████████| 5/5 [00:21<00:00,  4.27s/it]
#
# >> percentages:  40%|████      | 2/5 [00:28<00:33, 11.22s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:09<00:36,  9.02s/it]
#
# rounds:  40%|████      | 2/5 [00:18<00:27,  9.13s/it]
#
# rounds:  60%|██████    | 3/5 [00:27<00:18,  9.10s/it]
#
# rounds:  80%|████████  | 4/5 [00:36<00:09,  9.18s/it]
#
# rounds: 100%|██████████| 5/5 [00:45<00:00,  9.17s/it]
#
# >> percentages:  60%|██████    | 3/5 [01:14<00:43, 21.63s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:19<01:18, 19.53s/it]
#
# rounds:  40%|████      | 2/5 [00:40<00:59, 19.83s/it]
#
# rounds:  60%|██████    | 3/5 [01:00<00:40, 20.02s/it]
#
# rounds:  80%|████████  | 4/5 [01:21<00:20, 20.46s/it]
#
# rounds: 100%|██████████| 5/5 [01:42<00:00, 20.60s/it]
#
# >> percentages:  80%|████████  | 4/5 [02:57<00:46, 46.06s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [01:05<04:21, 65.37s/it]
#
# rounds:  40%|████      | 2/5 [02:09<03:14, 64.99s/it]
#
# rounds:  60%|██████    | 3/5 [03:14<02:10, 65.10s/it]
#
# rounds:  80%|████████  | 4/5 [04:18<01:04, 64.78s/it]
#
# rounds: 100%|██████████| 5/5 [05:24<00:00, 64.94s/it]
#
# >> percentages: 100%|██████████| 5/5 [08:22<00:00, 100.41s/it]
# methods:  75%|███████▌  | 3/4 [15:23<05:32, 332.37s/it]
# >> percentages:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:03<00:15,  3.78s/it]
#
# rounds:  40%|████      | 2/5 [00:10<00:13,  4.58s/it]
#
# rounds:  60%|██████    | 3/5 [00:14<00:09,  4.58s/it]
#
# rounds:  80%|████████  | 4/5 [00:18<00:04,  4.28s/it]
#
# rounds: 100%|██████████| 5/5 [00:22<00:00,  4.48s/it]
#
# >> percentages:  20%|██        | 1/5 [00:22<01:29, 22.45s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [00:04<00:18,  4.61s/it]
#
# rounds:  40%|████      | 2/5 [00:11<00:15,  5.21s/it]
#
# rounds:  60%|██████    | 3/5 [00:23<00:14,  7.22s/it]
#
# rounds:  80%|████████  | 4/5 [00:36<00:09,  9.11s/it]
#
# rounds: 100%|██████████| 5/5 [00:46<00:00,  9.30s/it]
#
# >> percentages:  40%|████      | 2/5 [01:09<01:29, 29.68s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [01:01<04:04, 61.03s/it]
#
# rounds:  40%|████      | 2/5 [01:55<02:56, 58.94s/it]
#
# rounds:  60%|██████    | 3/5 [02:49<01:54, 57.45s/it]
#
# rounds:  80%|████████  | 4/5 [03:01<00:44, 44.01s/it]
#
# rounds: 100%|██████████| 5/5 [03:56<00:00, 47.34s/it]
#
# >> percentages:  60%|██████    | 3/5 [05:05<03:03, 91.82s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [02:07<08:29, 127.32s/it]
#
# rounds:  40%|████      | 2/5 [04:14<06:21, 127.16s/it]
#
# rounds:  60%|██████    | 3/5 [06:34<04:22, 131.09s/it]
#
# rounds:  80%|████████  | 4/5 [08:45<02:11, 131.01s/it]
#
# rounds: 100%|██████████| 5/5 [11:12<00:00, 134.55s/it]
#
# >> percentages:  80%|████████  | 4/5 [16:18<04:26, 266.11s/it]
#
# rounds:   0%|          | 0/5 [00:00<?, ?it/s]
#
# rounds:  20%|██        | 1/5 [10:44<42:58, 644.51s/it]
#
# rounds:  40%|████      | 2/5 [21:31<32:15, 645.32s/it]
#
# rounds:  60%|██████    | 3/5 [31:58<21:19, 639.77s/it]
#
# rounds:  80%|████████  | 4/5 [42:31<10:37, 637.68s/it]
#
# rounds: 100%|██████████| 5/5 [52:47<00:00, 633.47s/it]
#
# >> percentages: 100%|██████████| 5/5 [1:09:06<00:00, 829.21s/it]
# methods: 100%|██████████| 4/4 [1:24:29<00:00, 1267.40s/it]

# %%
plot_multi_method_accs(methods_accs, percentages, methods.keys())
